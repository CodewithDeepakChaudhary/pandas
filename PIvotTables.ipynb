# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    386     47   John  January      Q1
# 1  2023-01-02       B   West    617     50   Mary  January      Q1
# 2  2023-01-03       C  North    983     27    Bob  January      Q1
# 3  2023-01-04       D  South    189     98  Alice  January      Q1
# 4  2023-01-05       A   East    102     96   John  January      Q1
# 5  2023-01-06       B   West    512     85   Mary  January      Q1
# 6  2023-01-07       C  North    444     72    Bob  January      Q1
# 7  2023-01-08       D  South    596     91  Alice  January      Q1
# 8  2023-01-09       A   East    943     83   John  January      Q1
# 9  2023-01-10       B   West    626     30   Mary  January      Q1
# 10 2023-01-11       C  North    462     87    Bob  January      Q1
# 11 2023-01-12       D  South    890     75  Alice  January      Q1
# 12 2023-01-13       A   East    174     49   John  January      Q1
# 13 2023-01-14       B   West    196     87   Mary  January      Q1
# 14 2023-01-15       C  North    313     85    Bob  January      Q1
# 15 2023-01-16       D  South    611     25  Alice  January      Q1
# 16 2023-01-17       A   East    580     34   John  January      Q1
# 17 2023-01-18       B   West    690     39   Mary  January      Q1
# 18 2023-01-19       C  North    278     47    Bob  January      Q1
# 19 2023-01-20       D  South    416     20  Alice  January      Q1

# %%
# create own pivot table  ->values must be numeric,  bydefault aggfun = mean
# usecase -> heat map etc
pd.pivot_table(df,values='Sales', index='Region', columns='Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     386.0    NaN    NaN    NaN
# North      NaN    NaN  444.0    NaN
# South      NaN    NaN    NaN  596.0
# West       NaN  617.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=['Sales','Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     437.0    NaN    NaN    NaN  61.8   NaN   NaN   NaN
# North      NaN    NaN  496.0    NaN   NaN   NaN  63.6   NaN
# South      NaN    NaN    NaN  540.4   NaN   NaN   NaN  61.8
# West       NaN  528.2    NaN    NaN   NaN  58.2   NaN   NaN

# %% [markdown]
# Cross Tabs

# %%
# crosstab()  ->used for counting purpose, bydefault aggfun = count
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
